# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Shaaf\Desktop\Data Science\ML-Ops\Git & Github\sales_data.csv")

# %%
df
# Out:
#              Date Store ID Product ID     Category Region  Inventory Level  \
# 0      2022-01-01     S001      P0001  Electronics  North              195
# 1      2022-01-01     S001      P0002     Clothing  North              117
# 2      2022-01-01     S001      P0003     Clothing  North              247
# 3      2022-01-01     S001      P0004  Electronics  North              139
# 4      2022-01-01     S001      P0005    Groceries  North              152
# ...           ...      ...        ...          ...    ...              ...
# 75995  2024-01-30     S005      P0016         Toys  North              233
# 75996  2024-01-30     S005      P0017         Toys  North              137
# 75997  2024-01-30     S005      P0018     Clothing  North              197
# 75998  2024-01-30     S005      P0019    Furniture  North              125
# 75999  2024-01-30     S005      P0020         Toys  North              126
#
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Price', 'Discount',
#        'Weather Condition', 'Promotion', 'Competitor Pricing', 'Seasonality',
#        'Epidemic', 'Demand'],
#       dtype='object')

# %%
itmes_sold=pd.DataFrame(df.groupby(['Region','Weather Condition','Category'])['Units Sold'].sum().reset_index())

# %%
itmes_sold
# Out:
#    Region Weather Condition     Category  Units Sold
# 0    East            Cloudy     Clothing       47613
# 1    East            Cloudy  Electronics       67364
# 2    East            Cloudy    Furniture       45905
# 3    East            Cloudy    Groceries      224058
# 4    East            Cloudy         Toys       59059
# ..    ...               ...          ...         ...
# 71   West             Snowy    Groceries       70805
# 72   West             Sunny     Clothing      126830
# 73   West             Sunny  Electronics       19561
# 74   West             Sunny    Furniture      123327
# 75   West             Sunny    Groceries      202346
#
# [76 rows x 4 columns]

# %%
sns.barplot(x='Category', y='Units Sold', hue='Region', data=itmes_sold, palette='viridis')
# Out:
# <Axes: xlabel='Category', ylabel='Units Sold'>

# %%
g = sns.catplot(
    data=itmes_sold,
    x='Category',
    y='Units Sold',
    hue='Region',
    col='Weather Condition',
    kind='bar',
    height=5,
    
)

plt.tight_layout()
plt.show()

# %%
itmes_sold
# Out:
#    Region Weather Condition     Category  Units Sold
# 0    East            Cloudy     Clothing       47613
# 1    East            Cloudy  Electronics       67364
# 2    East            Cloudy    Furniture       45905
# 3    East            Cloudy    Groceries      224058
# 4    East            Cloudy         Toys       59059
# ..    ...               ...          ...         ...
# 71   West             Snowy    Groceries       70805
# 72   West             Sunny     Clothing      126830
# 73   West             Sunny  Electronics       19561
# 74   West             Sunny    Furniture      123327
# 75   West             Sunny    Groceries      202346
#
# [76 rows x 4 columns]

# %%
#let's plot the total sales by region
df
# Out:
#             Date Store ID Product ID     Category Region  Inventory Level  \
# 0     2022-01-01     S001      P0001  Electronics  North              195
# 1     2022-01-01     S001      P0002     Clothing  North              117
# 2     2022-01-01     S001      P0003     Clothing  North              247
# 3     2022-01-01     S001      P0004  Electronics  North              139
# 4     2022-01-01     S001      P0005    Groceries  North              152
# ...          ...      ...        ...          ...    ...              ...
# 75995 2024-01-30     S005      P0016         Toys  North              233
# 75996 2024-01-30     S005      P0017         Toys  North              137
# 75997 2024-01-30     S005      P0018     Clothing  North              197
# 75998 2024-01-30     S005      P0019    Furniture  North              125
# 75999 2024-01-30     S005      P0020         Toys  North              126
#
#        Units Sold  Units Ordered   Price  Discount Weather Condition  \
# ...

# %%
df['Sale Value']= df['Units Sold'] * df['Price']

# %%
df
# Out:
#             Date Store ID Product ID     Category Region  Inventory Level  \
# 0     2022-01-01     S001      P0001  Electronics  North              195
# 1     2022-01-01     S001      P0002     Clothing  North              117
# 2     2022-01-01     S001      P0003     Clothing  North              247
# 3     2022-01-01     S001      P0004  Electronics  North              139
# 4     2022-01-01     S001      P0005    Groceries  North              152
# ...          ...      ...        ...          ...    ...              ...
# 75995 2024-01-30     S005      P0016         Toys  North              233
# 75996 2024-01-30     S005      P0017         Toys  North              137
# 75997 2024-01-30     S005      P0018     Clothing  North              197
# 75998 2024-01-30     S005      P0019    Furniture  North              125
# 75999 2024-01-30     S005      P0020         Toys  North              126
#
#        Units Sold  Units Ordered   Price  Discount Weather Condition  \
# ...

# %%
items_sold_by_region = pd.DataFrame(df.groupby(['Region'])['Sale Value'].sum().reset_index())
items_sold_by_region.sort_values(by='Sale Value', ascending=False, inplace=True)

# %%
items_sold_by_region['Sale Value'] = items_sold_by_region['Sale Value'].apply(lambda x: f"{x:.2f}")

# %%
items_sold_by_region
# Out:
#   Region    Sale Value
# 1  North  170008022.90
# 0   East   98526308.33
# 3   West   94466923.20
# 2  South   92298840.07

# %%
sns.barplot(x='Region', y='Sale Value', data=itmes_sold_by_region, width=0.4,palette='viridis')
# Out:
# C:\Users\Shaaf\AppData\Local\Temp\ipykernel_13192\665178731.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Region', y='Sale Value', data=itmes_sold_by_region, width=0.4,palette='viridis')
# <Axes: xlabel='Region', ylabel='Sale Value'>

# %%
df['Demand'] = df['Inventory Level']-(df['Units Ordered']-df['Units Sold'])

# %%
df
# Out:
#             Date Store ID Product ID     Category Region  Inventory Level  \
# 0     2022-01-01     S001      P0001  Electronics  North              195
# 1     2022-01-01     S001      P0002     Clothing  North              117
# 2     2022-01-01     S001      P0003     Clothing  North              247
# 3     2022-01-01     S001      P0004  Electronics  North              139
# 4     2022-01-01     S001      P0005    Groceries  North              152
# ...          ...      ...        ...          ...    ...              ...
# 75995 2024-01-30     S005      P0016         Toys  North              233
# 75996 2024-01-30     S005      P0017         Toys  North              137
# 75997 2024-01-30     S005      P0018     Clothing  North              197
# 75998 2024-01-30     S005      P0019    Furniture  North              125
# 75999 2024-01-30     S005      P0020         Toys  North              126
#
#        Units Sold  Units Ordered   Price  Discount Weather Condition  \
# ...

# %%
df =pd.g
